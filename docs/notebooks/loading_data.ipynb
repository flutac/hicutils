# %% [markdown]
# ## From ImmuneDB Link
# For a hosted ImmuneDB instance, you can directly download and load data from the website link. Depending on the database size, initially gathering the data may take some time.  After it is downloaded, the cached version will be used unless the data is explicitly deleted.

# %%
import hicutils.core.io as io

df = io.pull_immunedb_data(
    'https://myurl.com/immunedb',
    'mydb',
    'example_data_immunedb'
)

# Show a snippet of the resulting DataFrame
df[['clone_id', 'subject', 'v_gene', 'j_gene', 'cdr3_aa', 'copies', 'shm']]
# Out:
#       clone_id  subject          v_gene j_gene                        cdr3_aa  \
# 8248   6311533  HPAP015         IGHV2-5  IGHJ4              CAHSWVRYNSGWGFHYW
# 9810   6326493  HPAP015  IGHV2-70|2-70D  IGHJ4               CARPHGSSGWYYFDYW
# 8697   6315829  HPAP015         IGHV2-5  IGHJ4                CARGQWLAPNHFDYW
# 7970   6308963  HPAP015         IGHV2-5  IGHJ4                    CAHRGSSWDYW
# 8549   6314347  HPAP015         IGHV2-5  IGHJ4                CAHSTIRFQYYFDSW
# ...        ...      ...             ...    ...                            ...
# 4137   7029341  HPAP017        IGHV1-46  IGHJ3  CAAVRYYDSSGYFAAGDSDYGRAGAFDIW
# 4135   7029336  HPAP017        IGHV1-46  IGHJ3           CAAANYYDXSGYYHYAFDIW
# 4134   7029309  HPAP017        IGHV1-46  IGHJ3           CARDLYDSIGYYRAXAFDIW
# 4133   7029295  HPAP017        IGHV1-46  IGHJ3            XARDKYSGSYYLSDAFDIW
# 9999   7116522  HPAP017        IGHV3-11  IGHJ6             CARAYSYGQYYYYGMDVW
#
#       copies   shm
# 8248      34  1.14
# 9810      31  4.34
# 8697      27  4.56
# 7970      24  1.37
# 8549      22  3.01
# ...      ...   ...
# 4137       1  3.32
# 4135       1  3.79
# 4134       1  2.31
# 4133       1  0.46
# 9999       1  6.98
#
# [40000 rows x 7 columns]

# %% [markdown]
# ## From existing files with metadata in filenames
# Alternatively, if you have existing files which were exported from ImmuneDB (either using `immunedb_export ... clones ...` or via the website), they can be imported directly.  Take for example the files below:

# %%
# %%bash
# ls example_data_meta_in_names
# Out:
# HPAP015.T1D.pooled.tsv
# HPAP017.Control.pooled.tsv

# %% [markdown]
# The files can be imported with the following:

# %%
import hicutils.core.io as io

# Specify that the metadata in the filename is the disease status
# If there are multiple features separated with the _AND_ string
# per the ImmuneDB specification, the second parameter should
# be a list of all features (e.g. for age and siease ['age', 'disease'].
df = io.read_tsvs('example_data_meta_in_names', ['disease'])

# Show a snippet of the resulting DataFrame
df[['clone_id', 'subject', 'v_gene', 'j_gene', 'cdr3_aa', 'copies', 'shm']]
# Out:
#        clone_id  subject          v_gene   j_gene                    cdr3_aa  \
# 16548   6310562  HPAP015         IGHV2-5  IGHJ4|5                  CARARGAYW
# 16771   6311533  HPAP015         IGHV2-5    IGHJ4          CAHSWVRYNSGWGFHYW
# 19430   6326493  HPAP015  IGHV2-70|2-70D    IGHJ4           CARPHGSSGWYYFDYW
# 17713   6315829  HPAP015         IGHV2-5    IGHJ4            CARGQWLAPNHFDYW
# 7648    6262779  HPAP015         IGHV1-3    IGHJ4           CARAVENHFDWLSNYW
# ...         ...      ...             ...      ...                        ...
# 8487    7016857  HPAP017         IGHV1-3    IGHJ3      XXRQGA*QWLVLWGGDAFDIW
# 8488    7016859  HPAP017         IGHV1-3    IGHJ3  CARVMVGYSGYGGXYXVSGYAFDIW
# 8492    7016881  HPAP017         IGHV1-3    IGHJ3   CARGGXRQRVANYXGSGRGAFDIW
# 8493    7016885  HPAP017         IGHV1-3    IGHJ3       CARVSSYGWESAGPDAFDXW
# 19892   7116522  HPAP017        IGHV3-11    IGHJ6         CARAYSYGQYYYYGMDVW
#
#        copies       shm
# 16548      41  4.415122
# 16771      34  1.140000
# 19430      31  4.340000
# 17713      30  4.629000
# 7648       30  5.996667
# ...       ...       ...
# 8487        1  3.270000
# 8488        1  2.790000
# 8492        1  4.190000
# 8493        1  4.650000
# 19892       1  6.980000
#
# [39513 rows x 7 columns]

# %% [markdown]
# ## From existing replicate files and metadata file

# %% [markdown]
# Finally, if you have AIRR-seq files for each replicate and a metadata file, use the following to load the data.

# %%
# %%bash
# ls example_data_immunedb
# Out:
# HPAP015.IgH_HPAP015_rep1_200p0ng.pooled.tsv
# HPAP015.IgH_HPAP015_rep2_200p0ng.pooled.tsv
# HPAP017.IgH_HPAP017_rep1_200p0ng.pooled.tsv
# HPAP017.IgH_HPAP017_rep2_200p0ng.pooled.tsv
# metadata.tsv

# %%
import hicutils.core.io as io

df = io.read_directory('example_data_immunedb')

# Show a snippet of the resulting DataFrame
df[['clone_id', 'subject', 'v_gene', 'j_gene', 'cdr3_aa', 'copies', 'shm']]
# Out:
#       clone_id  subject          v_gene j_gene                        cdr3_aa  \
# 8248   6311533  HPAP015         IGHV2-5  IGHJ4              CAHSWVRYNSGWGFHYW
# 9810   6326493  HPAP015  IGHV2-70|2-70D  IGHJ4               CARPHGSSGWYYFDYW
# 8697   6315829  HPAP015         IGHV2-5  IGHJ4                CARGQWLAPNHFDYW
# 7970   6308963  HPAP015         IGHV2-5  IGHJ4                    CAHRGSSWDYW
# 8549   6314347  HPAP015         IGHV2-5  IGHJ4                CAHSTIRFQYYFDSW
# ...        ...      ...             ...    ...                            ...
# 4137   7029341  HPAP017        IGHV1-46  IGHJ3  CAAVRYYDSSGYFAAGDSDYGRAGAFDIW
# 4135   7029336  HPAP017        IGHV1-46  IGHJ3           CAAANYYDXSGYYHYAFDIW
# 4134   7029309  HPAP017        IGHV1-46  IGHJ3           CARDLYDSIGYYRAXAFDIW
# 4133   7029295  HPAP017        IGHV1-46  IGHJ3            XARDKYSGSYYLSDAFDIW
# 9999   7116522  HPAP017        IGHV3-11  IGHJ6             CARAYSYGQYYYYGMDVW
#
#       copies   shm
# 8248      34  1.14
# 9810      31  4.34
# 8697      27  4.56
# 7970      24  1.37
# 8549      22  3.01
# ...      ...   ...
# 4137       1  3.32
# 4135       1  3.79
# 4134       1  2.31
# 4133       1  0.46
# 9999       1  6.98
#
# [40000 rows x 7 columns]
